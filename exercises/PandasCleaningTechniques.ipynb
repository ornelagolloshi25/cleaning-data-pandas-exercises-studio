# %% [markdown]
# # Cleaning Data with Pandas Exercises
#
# For the exercises, you will be cleaning data in the Women's Clothing E-Commerce Reviews dataset.
#
# **Dataset Information:**
# - **Dataset Name:** Women's Clothing E-Commerce Reviews
# - **File:** `Womens Clothing E-Commerce Reviews.csv`
# - **Source:** This dataset contains reviews written by customers and includes features like ratings, review text, product categories, and customer information.
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here.
import pandas as pd

# Create a new dataframe from your CSV
#df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")
df = pd.read_csv(r"F:\@ornela@\Launch Code\2509 Part Time Data Analysis\workplace\cleaning-data-pandas-exercises-studio\exercises\Womens Clothing E-Commerce Reviews.csv")

# %%
# Print out any information you need to understand your dataframe
df.describe()
df.info()
df.shape
df.head()
df.tail()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %% [markdown]
# ## Missing Data
#
# Try out different methods to locate and resolve missing data.

# %%
# Try to find some missing data!

# Count missing values per column
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
# Boolean mask of missing values
df.isnull()
# Out:
#        Unnamed: 0  Clothing ID    Age  Title  Review Text  Rating  \
# 0           False        False  False   True        False   False
# 1           False        False  False   True        False   False
# 2           False        False  False  False        False   False
# 3           False        False  False  False        False   False
# 4           False        False  False  False        False   False
# ...           ...          ...    ...    ...          ...     ...
# 23481       False        False  False  False        False   False
# 23482       False        False  False  False        False   False
# 23483       False        False  False  False        False   False
# 23484       False        False  False  False        False   False
# 23485       False        False  False  False        False   False
#
#        Recommended IND  Positive Feedback Count  Division Name  \
# 0                False                    False          False
# 1                False                    False          False
# 2                False                    False          False
# 3                False                    False          False
# 4                False                    False          False
# ...                ...                      ...            ...
# 23481            False                    False          False
# 23482            False                    False          False
# 23483            False                    False          False
# 23484            False                    False          False
# 23485            False                    False          False
#
#        Department Name  Class Name
# 0                False       False
# 1                False       False
# 2                False       False
# 3                False       False
# 4                False       False
# ...                ...         ...
# 23481            False       False
# 23482            False       False
# 23483            False       False
# 23484            False       False
# 23485            False       False
#
# [23486 rows x 11 columns]

# %%
# Percentage of missing values per column
df.isnull().mean() * 100
# Out:
# Unnamed: 0                  0.000000
# Clothing ID                 0.000000
# Age                         0.000000
# Title                      16.222430
# Review Text                 3.597888
# Rating                      0.000000
# Recommended IND             0.000000
# Positive Feedback Count     0.000000
# Division Name               0.059610
# Department Name             0.059610
# Class Name                  0.059610
# dtype: float64

# %%
# Quick overview with info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Did you find any missing data? What things worked well for you and what did not?

# %%
# Respond to the above questions here:
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
# Drop rows with any missing values
df_cleaned = df.dropna()

# %%
#Check the cleaned df
df_cleaned.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers.

# %%
# Keep an eye out for outliers!
df_cleaned.plot.scatter(x= "Age", y = 'Positive Feedback Count')
# Out:
# <Axes: xlabel='Age', ylabel='Positive Feedback Count'>

# %% [markdown]
# What techniques helped you find outliers? In your opinion, what about the techniques you used made them effective?

# %%
# Make your notes here:
'''
This method was effective because it provides a summary of the entire dataset,
making unusual values easy to identify without the need for graphs.
'''

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be irrelevant to your analysis or a duplicate column. Check out the dataset to see if there is any unnecessary data.

# %%
# Look out for unnecessary data!
df_cleaned.drop(['Unnamed: 0'], axis = 1)
df_cleaned.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Clothing ID, Age, Title, Review Text, Rating, Recommended IND, Positive Feedback Count, Division Name, Department Name, Class Name]
# Index: []

# %% [markdown]
# Did you find any unnecessary data in your dataset? How did you handle it?

# %%
# Make your notes here.
'''
Certain columns—such as Clothing ID or Title—may not be necessary depending on the analysis.
To manage this, I reviewed all column names with df.columns and used df.drop()
to remove those that were not relevant to my analysis.
'''

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Look out for inconsistent data!

# %% [markdown]
# Did you find any inconsistent data? What did you do to clean it?

# %%
# Make your notes here!
'''
To clean the dataset, I applied .str.lower() to convert all text to lowercase
and .str.strip() to remove any extra spaces. I also ensured that numeric columns
were stored with the correct data types.
'''
